# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <p style="font-family: Arial; font-size:2.75em;color:purple; font-style:bold">
# Classify the user using scikit-learn
#
# <br><br>
# </p>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#
# Importing the Necessary Libraries<br></p>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#
# Creating a Pandas DataFrame from a CSV file<br></p>

# %%
data1 = pd.read_csv('Crimes_-_2001_to_present.csv')

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold">Daily Weather Data Description</p>
# <br>
# The file **2017Q1-capitalbikeshare-tripdata.csv** is a comma-separated file that contains bike sharing data.  This data comes from a bike sharing service in US.  Data was collected for a period of one year and was divided into four quaters<br><br>
# Let's now check all the columns in the data.

# %%
data1.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
data1
# Out:
#                ID Case Number                    Date  \
# 0        10000092    HY189866  03/18/2015 07:44:00 PM
# 1        10000094    HY190059  03/18/2015 11:00:00 PM
# 2        10000095    HY190052  03/18/2015 10:45:00 PM
# 3        10000096    HY190054  03/18/2015 10:30:00 PM
# 4        10000097    HY189976  03/18/2015 09:00:00 PM
# 5        10000098    HY190032  03/18/2015 10:00:00 PM
# 6        10000099    HY190047  03/18/2015 11:00:00 PM
# 7        10000100    HY189988  03/18/2015 09:35:00 PM
# 8        10000101    HY190020  03/18/2015 10:09:00 PM
# 9        10000104    HY189964  03/18/2015 09:25:00 PM
# 10       10000105    HY189984  03/18/2015 09:30:00 PM
# 11       10000108    HY189719  03/15/2015 04:10:00 PM
# 12       10000109    HY189966  03/18/2015 09:14:00 PM
# 13       10000110    HY190056  03/18/2015 10:50:00 PM
# 14       10000111    HY190019  03/18/2015 10:31:00 PM
# 15       10000112    HY189725  03/18/2015 12:55:00 PM
# ...

# %%
data1.shape[0]
# Out:
# 646510

# %% [markdown]
# **We are going to check weather any row in this data is empty or not **

# %%
data1[data1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type]
# Index: []

# %% [markdown]
# **We don't require the bike number, so we are going to delete the column.**

# %%
before_rows = data1.shape[0]

# %%
data1 = data1.dropna()

# %%
after_rows = data1.shape[0]

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#
# How many rows dropped due to cleaning?<br><br></p>

# %%
before_rows -after_rows
# Out:
# 0

# %%
data1['Bike number'].unique().shape[0]
# Out:
# 4298

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-0dc172e2fbd4> in <module>()
# ...

# %% [markdown]
# **Checking the highest for a member and the lowest for a casual user**

# %%
grouped_data = data1['Duration'].groupby(data1['Member type'])
print(grouped_data)

# %%
average_duration = grouped_data.mean()
print(average_duration)
# Out:
# Member type
# Casual    2445.304880
# Member     689.832496
# Name: Duration, dtype: float64

# %%
maximum_duration = grouped_data.max()
maximum_duration
# Out:
# Member type
# Casual    86066
# Member    85980
# Name: Duration, dtype: int64

# %%
minimum_duration = grouped_data.min()
minimum_duration
# Out:
# Member type
# Casual    60
# Member    60
# Name: Duration, dtype: int64

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold">
# Convert to a Classification Task <br><br></p>
# Binarize the relative_humidity_3pm to 0 or 1.<br>

# %%
clean_data = data1.copy()
is_animation = movies['genres'].str.contains('Animation')
